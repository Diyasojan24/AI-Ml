# %% [markdown]
# <a href="https://colab.research.google.com/github/Diyasojan24/AI-Ml/blob/main/LR_salary_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
df=pd.read_excel("/content/Salary_dataset.xlsx")
df.head()
# Out:
#    Unnamed: 0  YearsExperience  Salary
# 0           0              1.2   39344
# 1           1              1.4   46206
# 2           2              1.6   37732
# 3           3              2.1   43526
# 4           4              2.3   39892

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.dtypes
# Out:
# YearsExperience    float64
# Salary               int64
# dtype: object

# %%
plt.title("Year of Experience vs salary")
plt.xlabel("Year of Experience")
plt.ylabel("Salary")
plt.scatter(df['YearsExperience'],df['Salary'])
plt.show()

# %%
x=df.iloc[:,0].values
y=df.iloc[:,-1].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LinearRegression()
lr.fit(x_train.reshape(-1,1),y_train.reshape(-1,1))
y_predict=lr.predict(x_test.reshape(-1,1))

# %%
print(y_predict)
print(y_test)
# Out:
# [[115791.21011287]
#  [ 71499.27809463]
#  [102597.86866063]
#  [ 75268.80422384]
#  [ 55478.79204548]
#  [ 60190.69970699]]
# [112636  67939 113813  83089  64446  57190]

# %%
plt.title("Year of Experience vs salary")
plt.xlabel("Year of Experience")
plt.ylabel("Salary")
plt.scatter(df['YearsExperience'],df['Salary'])
plt.plot(x_test,y_predict,color="red")
plt.show()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[9423.81532303]]
# [24380.20147947]

# %%
print(lr.predict([[7]]))
# Out:
# [[90346.90874069]]

# %%
sns.regplot(x=df['YearsExperience'],y=df['Salary'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
from sklearn.metrics import r2_score
print(mean_absolute_error(y_test,y_predict))
print(mean_squared_error(y_test,y_predict))
print(r2_score(y_test,y_predict))
print(np.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# 6286.4538307577795
# 49830096.85590884
# 0.9024461774180488
# 7059.043621901542
